# %% [markdown]
# <a href="https://colab.research.google.com/github/AnkurAa98/WebApplication1/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HI")
# Out:
# HI

# %%
num1 = 5
num2 = 10

sum_result = num1 + num2

print(f"The sum of {num1} and {num2} is: {sum_result}")
# Out:
# The sum of 5 and 10 is: 15

# %%
num1_sub = 20
num2_sub = 7

subtraction_result = num1_sub - num2_sub

print(f"The difference between {num1_sub} and {num2_sub} is: {subtraction_result}")
# Out:
# The difference between 20 and 7 is: 13
